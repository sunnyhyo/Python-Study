# %%
import pandas as pd

# %%
item_metadata = pd.read_csv('C:/Users/HS/Documents/GitHub/Recommendation system/data/item_metadata_v2.csv')

# %%
item_matadata = item_metadata.head(10000)
item_matadata.head()
# Out:
#    item_id                                         properties
# 0     5101  Satellite TV|Golf Course|Airport Shuttle|Cosme...
# 1     5416  Satellite TV|Cosmetic Mirror|Safe (Hotel)|Tele...
# 2     5834  Satellite TV|Cosmetic Mirror|Safe (Hotel)|Tele...
# 3     5910  Satellite TV|Sailing|Cosmetic Mirror|Telephone...
# 4     6066  Satellite TV|Sailing|Diving|Cosmetic Mirror|Sa...

# %% [markdown]
# <방법 1> : 0부터 N-1까지 for문을 돌면서 계속 append해 나가는 방법입니다.
#     append라는 함수 자체가 기존에 할당된 공간을 확장해야 하기 때문에, 만약에 연속된 메모리의 자리가 없을 경우 새롭게 큰 공간을 만들어 모든 값들을 이사시켜야 하는 단점이 있습니다. 여기서 바로 꽤나 큰 overhead가 발생하게 되서 상대적으로 느립니다.

# %%
def makeListUsingAppend(N):
    result = []
    for i in range(N):
        result.append(i)
    return result

# %% [markdown]
# <방법 2> : 이번 방법은 조금 더 smart합니다. 이미 우리는 얼마나 큰 공간을 만들어야 하는지 알기 때문에, 미리 N개의 공간을 만들어 놓고, 값만 바꿔줍니다. 실제로 메모리 할당에 드는 overhead가 가장 무지막지하기 때문에 이 방법은 1.5배 정도까지 시간을 줄여주네요.

# %%
def makeListUsingBulkAlloc(N):
    result = [0]*N #한번에 N개의 공간을 0으로 채우는 방법입니다.
    for i in range(N):
        result[i] = i
    return result

# %%
item_matadata.head()
# Out:
#    item_id                                         properties
# 0     5101  Satellite TV|Golf Course|Airport Shuttle|Cosme...
# 1     5416  Satellite TV|Cosmetic Mirror|Safe (Hotel)|Tele...
# 2     5834  Satellite TV|Cosmetic Mirror|Safe (Hotel)|Tele...
# 3     5910  Satellite TV|Sailing|Cosmetic Mirror|Telephone...
# 4     6066  Satellite TV|Sailing|Diving|Cosmetic Mirror|Sa...

# %% [markdown]
# <1번 방법> Dataframe -> Dictionary

# %%
item_metadata.set_index('item_id').head()
# Out:
#                                                 properties
# item_id
# 5101     Satellite TV|Golf Course|Airport Shuttle|Cosme...
# 5416     Satellite TV|Cosmetic Mirror|Safe (Hotel)|Tele...
# 5834     Satellite TV|Cosmetic Mirror|Safe (Hotel)|Tele...
# 5910     Satellite TV|Sailing|Cosmetic Mirror|Telephone...
# 6066     Satellite TV|Sailing|Diving|Cosmetic Mirror|Sa...

# %%
item_metadata.set_index('item_id').T
# Out:
# item_id                                              5101      \
# properties  Satellite TV|Golf Course|Airport Shuttle|Cosme...
#
# item_id                                              5416      \
# properties  Satellite TV|Cosmetic Mirror|Safe (Hotel)|Tele...
#
# item_id                                              5834      \
# properties  Satellite TV|Cosmetic Mirror|Safe (Hotel)|Tele...
#
# item_id                                              5910      \
# properties  Satellite TV|Sailing|Cosmetic Mirror|Telephone...
#
# item_id                                              6066      \
# properties  Satellite TV|Sailing|Diving|Cosmetic Mirror|Sa...
#
# item_id                                              6094      \
# properties  Satellite TV|Sailing|Safe (Hotel)|Telephone|Ho...
#
# item_id                                              6288      \
# properties  Satellite TV|Airport Shuttle|Cosmetic Mirror|S...
#
# item_id                                              6358      \
# ...

# %%
item_metadata.set_index('item_id').T.to_dict('records')[0]
# Out:
# {5101: 'Satellite TV|Golf Course|Airport Shuttle|Cosmetic Mirror|Safe (Hotel)|Telephone|Hotel|Sitting Area (Rooms)|Reception (24/7)|Air Conditioning|Hypoallergenic Rooms|Cable TV|Hotel Bar|Pool Table|Bathtub|Satisfactory Rating|Room Service|Luxury Hotel|Terrace (Hotel)|Television|Minigolf|Business Hotel|Shower|Cot|Gym|Hairdryer|Hypoallergenic Bedding|Accessible Parking|From 3 Stars|Good Rating|Radio|4 Star|From 4 Stars|Family Friendly|Desk|Tennis Court (Indoor)|Balcony|WiFi (Public Areas)|Openable Windows|Express Check-In / Check-Out|Restaurant|Laundry Service|Ironing Board|Tennis Court|From 2 Stars|Business Centre|Bowling|Conference Rooms|Electric Kettle|Accessible Hotel|Porter|Bike Rental|Non-Smoking Rooms|Car Park|Safe (Rooms)|Fitness|Fan|Flatscreen TV|Computer with Internet|WiFi (Rooms)|Lift|Central Heating',
# ...

# %% [markdown]
# <2번 방법> Series -> Dictionary

# %%
item_metadata.set_index('item_id').head()
# Out:
#                                                 properties
# item_id
# 5101     Satellite TV|Golf Course|Airport Shuttle|Cosme...
# 5416     Satellite TV|Cosmetic Mirror|Safe (Hotel)|Tele...
# 5834     Satellite TV|Cosmetic Mirror|Safe (Hotel)|Tele...
# 5910     Satellite TV|Sailing|Cosmetic Mirror|Telephone...
# 6066     Satellite TV|Sailing|Diving|Cosmetic Mirror|Sa...

# %%
pd.Series(data = item_metadata.set_index('item_id')['properties'], index=item_metadata.set_index('item_id').index )
# Out:
# item_id
# 5101        Satellite TV|Golf Course|Airport Shuttle|Cosme...
# 5416        Satellite TV|Cosmetic Mirror|Safe (Hotel)|Tele...
# 5834        Satellite TV|Cosmetic Mirror|Safe (Hotel)|Tele...
# 5910        Satellite TV|Sailing|Cosmetic Mirror|Telephone...
# 6066        Satellite TV|Sailing|Diving|Cosmetic Mirror|Sa...
# 6094        Satellite TV|Sailing|Safe (Hotel)|Telephone|Ho...
# 6288        Satellite TV|Airport Shuttle|Cosmetic Mirror|S...
# 6358        Cosmetic Mirror|Safe (Hotel)|Telephone|Hotel|C...
# 6456        Satellite TV|Cosmetic Mirror|Safe (Hotel)|Tele...
# 6561        Satellite TV|Golf Course|Cosmetic Mirror|Safe ...
# 6659        Satellite TV|Golf Course|Sailing|Resort|Airpor...
# 6853        Satellite TV|Sailing|Airport Shuttle|Diving|Sa...
# 7362        Satellite TV|Cosmetic Mirror|Telephone|Hotel|R...
# 7994        Satellite TV|Golf Course|Airport Shuttle|Safe ...
# 8476        Satellite TV|Sailing|Safe (Hotel)|Telephone|Ho...
# ...

# %%
pd.Series(data = item_metadata.set_index('item_id')['properties'], index=item_metadata.set_index('item_id').index ).to_dict()
# Out:
# {5101: 'Satellite TV|Golf Course|Airport Shuttle|Cosmetic Mirror|Safe (Hotel)|Telephone|Hotel|Sitting Area (Rooms)|Reception (24/7)|Air Conditioning|Hypoallergenic Rooms|Cable TV|Hotel Bar|Pool Table|Bathtub|Satisfactory Rating|Room Service|Luxury Hotel|Terrace (Hotel)|Television|Minigolf|Business Hotel|Shower|Cot|Gym|Hairdryer|Hypoallergenic Bedding|Accessible Parking|From 3 Stars|Good Rating|Radio|4 Star|From 4 Stars|Family Friendly|Desk|Tennis Court (Indoor)|Balcony|WiFi (Public Areas)|Openable Windows|Express Check-In / Check-Out|Restaurant|Laundry Service|Ironing Board|Tennis Court|From 2 Stars|Business Centre|Bowling|Conference Rooms|Electric Kettle|Accessible Hotel|Porter|Bike Rental|Non-Smoking Rooms|Car Park|Safe (Rooms)|Fitness|Fan|Flatscreen TV|Computer with Internet|WiFi (Rooms)|Lift|Central Heating',
# ...
